# %%
import cv2
import matplotlib.pyplot as plt
# Open the image
img = cv2.imread('alpacino.jpeg')

plt.figure()
plt.title('Al Pacino')
plt.imshow(img, cmap='gray')

# Apply Canny
edges = cv2.Canny(img, 100, 200, 3, L2gradient=True)
plt.figure()
plt.title('Al Pacino')
plt.imsave('result_alpacino.png', edges, cmap='gray', format='png')
plt.imshow(edges, cmap='gray')
plt.show()
